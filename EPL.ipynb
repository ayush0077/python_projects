# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome()
driver.get('https://www.espn.com/soccer/stats/_/league/ENG.1/season/2022/view/scoring')

# %%
data=driver.find_element(By.XPATH,'//html/body/div[1]/div/div/div/div/main/div[2]/div[2]/div/div/section/div/section/div/div[1]/section/div/div[2]/div/div[2]/table/tbody').text
data
# Out:
# '1 Erling Haaland Manchester City 35 36\n2 Harry Kane Tottenham Hotspur 38 30\n3 Ivan Toney Brentford 33 20\n4 Mohamed Salah Liverpool 38 19\n5 Callum Wilson Newcastle United 31 18\n6 Marcus Rashford Manchester United 35 17\n7 Martin Ødegaard Arsenal 37 15\nOllie Watkins Aston Villa 37 15\nGabriel Martinelli Arsenal 36 15\n10 Bukayo Saka Arsenal 38 14\nAleksandar Mitrovic Fulham 24 14\n12 Harvey Barnes Leicester City 34 13\nRodrigo Leeds United 31 13\n14 Miguel Almirón Newcastle United 34 11\nPhil Foden Manchester City 32 11\nGabriel Jesus Arsenal 26 11\nRoberto Firmino Liverpool 25 11\n18 Eberechi Eze Crystal Palace 38 10\nSon Heung-Min Tottenham Hotspur 36 10\nAlexis Mac Allister Brighton & Hove Albion 35 10\nJames Maddison Leicester City 30 10\nTaiwo Awoniyi Nottingham Forest 27 10\nAlexander Isak Newcastle United 22 10\n24 James Ward-Prowse Southampton 38 9\nBryan Mbeumo Brentford 38 9\nPascal Groß Brighton & Hove Albion 37 9\nJulián Álvarez Manchester City 31 9\nDarwin Núñez Liv
# ...

# %%
data.split('\n')
# Out:
# ['1 Erling Haaland Manchester City 35 36',
#  '2 Harry Kane Tottenham Hotspur 38 30',
#  '3 Ivan Toney Brentford 33 20',
#  '4 Mohamed Salah Liverpool 38 19',
#  '5 Callum Wilson Newcastle United 31 18',
#  '6 Marcus Rashford Manchester United 35 17',
#  '7 Martin Ødegaard Arsenal 37 15',
#  'Ollie Watkins Aston Villa 37 15',
#  'Gabriel Martinelli Arsenal 36 15',
#  '10 Bukayo Saka Arsenal 38 14',
#  'Aleksandar Mitrovic Fulham 24 14',
#  '12 Harvey Barnes Leicester City 34 13',
#  'Rodrigo Leeds United 31 13',
#  '14 Miguel Almirón Newcastle United 34 11',
#  'Phil Foden Manchester City 32 11',
#  'Gabriel Jesus Arsenal 26 11',
#  'Roberto Firmino Liverpool 25 11',
#  '18 Eberechi Eze Crystal Palace 38 10',
#  'Son Heung-Min Tottenham Hotspur 36 10',
#  'Alexis Mac Allister Brighton & Hove Albion 35 10',
#  'James Maddison Leicester City 30 10',
#  'Taiwo Awoniyi Nottingham Forest 27 10',
#  'Alexander Isak Newcastle United 22 10',
#  '24 James Ward-Prowse Southampton 38 9',
# ...

# %%
data.split('\n')[0]
# Out:
# '1 Erling Haaland Manchester City 35 36'

# %%
spli=data.split('\n')[0].split()
spli
# Out:
# ['1', 'Erling', 'Haaland', 'Manchester', 'City', '35', '36']

# %%
data.split('\n')[0]
# Out:
# '1 Erling Haaland Manchester City 35 36'

# %%
spli.insert(0,'Top Scorers')

# %%
spli
# Out:
# ['Top Scorers', '2', 'Harry', 'Kane', 'Tottenham', 'Hotspur', '38', '30']

# %%
spli.remove('Top Scorers')

# %%
spli
# Out:
# ['2', 'Harry', 'Kane', 'Tottenham', 'Hotspur', '38', '30']

# %%
player=data.split('\n')[0:]

# %%
import numpy as np

# %%
player=np.array(player)

# %%
player
# Out:
# array(['1 Erling Haaland Manchester City 35 36',
#        '2 Harry Kane Tottenham Hotspur 38 30',
#        '3 Ivan Toney Brentford 33 20', '4 Mohamed Salah Liverpool 38 19',
#        '5 Callum Wilson Newcastle United 31 18',
#        '6 Marcus Rashford Manchester United 35 17',
#        '7 Martin Ødegaard Arsenal 37 15',
#        'Ollie Watkins Aston Villa 37 15',
#        'Gabriel Martinelli Arsenal 36 15', '10 Bukayo Saka Arsenal 38 14',
#        'Aleksandar Mitrovic Fulham 24 14',
#        '12 Harvey Barnes Leicester City 34 13',
#        'Rodrigo Leeds United 31 13',
#        '14 Miguel Almirón Newcastle United 34 11',
#        'Phil Foden Manchester City 32 11', 'Gabriel Jesus Arsenal 26 11',
#        'Roberto Firmino Liverpool 25 11',
#        '18 Eberechi Eze Crystal Palace 38 10',
#        'Son Heung-Min Tottenham Hotspur 36 10',
#        'Alexis Mac Allister Brighton & Hove Albion 35 10',
#        'James Maddison Leicester City 30 10',
# ...

# %%
import pandas as pd
df=pd.DataFrame(player)
df
# Out:
# C:\Users\Ryzen\AppData\Local\Temp\ipykernel_23264\3272937446.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                                                    0
# 0             1 Erling Haaland Manchester City 35 36
# 1               2 Harry Kane Tottenham Hotspur 38 30
# 2                       3 Ivan Toney Brentford 33 20
# 3                    4 Mohamed Salah Liverpool 38 19
# 4             5 Callum Wilson Newcastle United 31 18
# 5          6 Marcus Rashford Manchester United 35 17
# 6                    7 Martin Ødegaard Arsenal 37 15
# ...

# %%
df=df[0].str.split(expand=True)

# %%
df['Name']=df[1].fillna('')+' '+df[2].fillna('')
df
# Out:
#              0           1              2            3        4       5  \
# 0            1      Erling        Haaland   Manchester     City      35
# 1            2       Harry           Kane    Tottenham  Hotspur      38
# 2            3        Ivan          Toney    Brentford       33      20
# 3            4     Mohamed          Salah    Liverpool       38      19
# 4            5      Callum         Wilson    Newcastle   United      31
# 5            6      Marcus       Rashford   Manchester   United      35
# 6            7      Martin       Ødegaard      Arsenal       37      15
# 7        Ollie     Watkins          Aston        Villa       37      15
# 8      Gabriel  Martinelli        Arsenal           36       15    None
# 9           10      Bukayo           Saka      Arsenal       38      14
# 10  Aleksandar    Mitrovic         Fulham           24       14    None
# 11          12      Harvey         Barnes    Leicester     City      34
# ...

# %%
df.columns
# Out:
# Index([0, 1, 2, 3, 4, 5, 6, 7, 8, 'Name'], dtype='object')
